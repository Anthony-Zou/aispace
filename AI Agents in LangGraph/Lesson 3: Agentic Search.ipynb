# %% [markdown]
# # Lesson 3: Agentic Search

# %%
# Libries
from dotenv import load_dotenv
import os
from tavily import TavilyClient

_ = load_dotenv()
load_dotenv('/home/jovyan/work/.env')  # Docker mounted directory
client = TavilyClient(api_key=os.getenv("TAVILY_API_KEY"))

# %%
result = client.search("What is in Nvidia's new Backwell GPU?",
                       include_answer=True)
print(result["answer"])
# Out:
# The Blackwell GPU features advanced FP4 precision, NVLink-5, and a multi-die design for high AI performance. It includes the Grace CPU Superchip and supports large models up to 200 billion parameters.

# %% [markdown]
# ## Regular Search

# %%
# Regular search
city = "San Francisco"

query = f"""
    what is the current weather in {city}?
    Should I travel there today?
    "weather.com"
"""

# %%
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS
import re

ddg = DDGS()

def search(query, max_results=6):
    try:
        results = ddg.text(query, max_results=max_results)
        return [i["href"] for i in results]
    except Exception as e:
        print(f"returning previous results due to exception reaching ddg.")
        results = [ # cover case where DDG rate limits due to high deeplearning.ai volume
            "https://weather.com/weather/today/l/USCA0987:1:US",
            "https://weather.com/weather/hourbyhour/l/54f9d8baac32496f6b5497b4bf7a277c3e2e6cc5625de69680e6169e7e38e9a8",
        ]
        return results  


for i in search(query):
    print(i)
# Out:
# /tmp/ipykernel_26783/2852339428.py:6: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddg = DDGS()
# https://zhidao.baidu.com/question/635787571195459284.html
# https://zhidao.baidu.com/question/374111504767740084.html
# https://zhidao.baidu.com/question/339397003791592205.html
# https://zhidao.baidu.com/question/434865041797516004.html
# https://zhidao.baidu.com/question/1251826788028159659.html
# https://zhidao.baidu.com/question/1443692925088265899.html

# %%
import requests
from bs4 import BeautifulSoup
from duckduckgo_search import DDGS
import re

ddg = DDGS()

def search(query, max_results=3):
    results = ddg.text(query, max_results=max_results)
    return [i["href"] for i in results]

for i in search(query):
    print(i)
# Out:
# /tmp/ipykernel_26783/1765662446.py:6: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   ddg = DDGS()

# %%
def scrape_weather_info(url):
    """Scrape content from the given URL"""
    if not url:
        return "Weather information could not be found."
    
    # fetch data
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the webpage."

    # parse result
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %%
# use DuckDuckGo to find websites and take the first result
url = search(query)[0]

# scrape first wesbsite
soup = scrape_weather_info(url)

print(f"Website: {url}\n\n")
print(str(soup.body)[:50000]) # limit long outputs
# Out:
# Website: https://zhidao.baidu.com/question/635787571195459284.html
#
#
# <body class="layout-center has-menu">
# <div class="userbar userbar-renew fixed qb-search" data="" id="userbar" left-width="880" width="" win-min-width="1280">
# <ul class="aside-list">
# <li>
# <a class="toindex" href="http://www.baidu.com/">ç¾åº¦é¦é¡µ</a>
# </li>
# <li class="shop-entrance">
# <a href="/shop" log="type:2026,pos:top-right,target:shop-entrance" title="ç¥éåå">åå<i class="i-house" style="display: none;"></i></a>
# <span class="lucky-try" style="display: none"></span>
# </li>
# <li><a alog-alias="usrbar-reg" href="https://passport.baidu.com/v2/?reg&amp;tpl=ik&amp;color=green&amp;u=" id="userbar-reg" rel="nofollow" target="_blank">æ³¨å</a></li>
# <li><a alog-alias="usrbar-login" href="javascript:;" id="userbar-login" log="type:2026,pname:account,mod:login,action:show,pos:pop" rel="nofollow">ç»å½</a></li>
# </ul>
# </div>
# <div class="head-wrap">
# <header class="container" id="header">
# <div class="search-box-new line search-box-new-all qb-search-box" id="search-box">
# <ul class="channel grid">
# <li>
# <a class="channel-item-ps" data-type="ps" href="//www.baidu.com/s?ie=utf-8&amp;wd=&amp;cl=3" log="sc_pos:c_ps" rel="nofollow">ç½é¡µ</a>
# </li>
# <li>
# <a class="channel-item-news" data-type="news" href="//www.baidu.com/s?rtt=1&amp;bsst=1&amp;cl=2&amp;tn=news&amp;ie=utf-8&amp;word=&amp;fr=zhidao&amp;dyTabStr=" log="sc_pos:c_news" rel="nofollow">èµè®¯</a>
# </li>
# <li>
# <a class="channel-item-video" data-type="video" href="//www.baidu.com/sf/vsearch?pd=video&amp;tn=vsearch&amp;ie=utf-8&amp;wd=&amp;rsv_spt=16&amp;dyTabStr=" log="sc_pos:c_video" rel="nofollow">è§é¢</a>
# </li>
# <li>
# <a class="channel-item-pic" data-type="pic" href="//image.baidu.com/search/index?tn=baiduimage&amp;ct=201326592&amp;lm=-1&amp;cl=2&amp;word=&amp;t=3&amp;dyTabStr=" log="sc_pos:c_pic" rel="nofollow">å¾ç</a>
# </li>
# <li><strong class="channel-item-zhidao">ç¥é</strong></li>
# <li>
# <a class="channel-item-wenku" data-type="wenku" href="//wenku.baidu.com/search?lm=0&amp;od=0&amp;word=&amp;dyTabStr=" log="sc_pos:c_wenku" rel="nofollow">æåº</a>
# </li>
# <li>
# <a class="channel-item-tieba" data-type="tieba" href="//tieba.baidu.com/f?kw=&amp;t=4&amp;dyTabStr=" log="sc_pos:c_tieba" rel="nofollow">è´´å§</a>
# </li>
# <li>
# <a class="channel-item-b2b" data-type="b2b" href="//b2b.baidu.com/s?q=&amp;fr=www" log="sc_pos:c_b2b" rel="nofollow">éè´­</a>
# </li>
# <li>
# <a class="channel-item-map" data-type="map" href="//map.baidu.com/?newmap=1&amp;ie=utf-8&amp;from=pstab&amp;s=s&amp;wd=&amp;fr=map007" log="sc_pos:c_map" rel="nofollow">å°å¾</a>
# </li>
# <li>
# <a class="channel-item-more" data-type="more" href="//www.baidu.com/more/" log="sc_pos:c_more" rel="nofollow">æ´å¤</a>
# </li>
# </ul>
# <div class="search-block clearfix">
# <div class="search-cont clearfix">
# <a class="logo" href="/" title="ç¾åº¦ç¥é"></a>
# <form action="/search" class="search-form" id="search-form-new" method="get" name="search-form">
# <input autocomplete="off" class="hdi" id="kw" maxlength="256" name="word" placeholder="" size="46" tabindex="1" value=""/>
# <button alog-action="g-search-anwser" class="btn-global" hidefocus="true" id="search-btn" tabindex="2" type="submit">æç´¢ç­æ¡</button>
# <a alog-action="g-i-ask" class="i-ask-link" href="#" id="ask-btn-new">æè¦æé®</a>
# </form>
# </div>
# </div>
# </div>
# <script>
#                         // æç´¢æ¡å¯ç¨æ¶é´æç¹
#                         window.iPerformance && window.iPerformance.mark('c_sbox', +new Date);
#                     </script>
# <div class="wgt-header-title">
# <div class="wgt-header-title-content">
# <h1 class="wgt-header-title-text">currentæ¯ä»ä¹ææ</h1>
# <span class="iknow-icons wgt-header-title-btn"> ææ¥ç­</span>
# </div>
# </div>
# </header>
# </div>
# <div class="nav-menu-container" id="j-nav-menu-container">
# <div class="nav-show-control">
# <div class="nav-menu-layout">
# <div class="nav-menu line">
# <div class="nav-menu-content container" style="width: 931px;">
# <div class="content-box">
# <div class="menu-item menu-item-index">
# <a class="menu-title" href="/">
# é¦é¡µ</a>
# </div>
# <div class="menu-item-box">
# <div class="menu-item menu-item-user">
# <a class="menu-title" href="javascript:;" style="cursor: default">
# ç¨æ·<img alt="" class="triangle_icon" src="https://iknow-zhidao.bdimg.com/static/common-new/widget/menu/img/triangle.47e7008.svg"/>
# </a>
# <div class="menu-content">
# <ul class="menu-sub-list">
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="cuser" href="https://baijiahao.baidu.com/builder/rc/rights/list" target="_blank">
# è®¤è¯ç¨æ·</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="cteam" href="/metis/team/decision?fr=daohang" target="_blank">
# è®¤è¯å¢é</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="menu-item menu-item-expert">
# <a class="menu-title" href="/home/partnerhome?fr=daohang" target="_blank">
# <span>
# åä¼äºº<img alt="" class="triangle_icon" src="https://iknow-zhidao.bdimg.com/static/common-new/widget/menu/img/triangle.47e7008.svg"/>
# </span>
# </a>
# <div class="menu-content">
# <ul class="menu-sub-list">
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="rank" href="/activity/page/partner-rank#/1?fr=daohang" target="_blank">
# ç­æ¨æ¦å</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="business" href="/home/partnerhome?fr=daohang" target="_blank">
# ä¼ä¸</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="media" href="/home/partnerhome?fr=daohang" target="_blank">
# åªä½</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="government" href="/home/partnerhome?fr=daohang" target="_blank">
# æ¿åº</a>
# </li>
# <li class="menu-sub-item-wp">
# <a class="menu-sub-item" data-type="other" href="/home/partnerhome?fr=daohang" target="_blank">
# å¶ä»ç»ç»</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="menu-right-section">
# <ul class="menu-right-list">
# <li class="menu-right-list-item zhidao-shop">
# <a class="menu-right-list-link" href="/shop" target="_blank">
# <span class="item-name">
# åå</span>
# <span class="new-icon"></span>
# </a>
# </li>
# <li class="menu-right-list-item">
# <a class="menu-right-list-link" href="/law/index" target="_blank">
# <span class="item-name">
# æ³å¾</span>
# </a>
# </li>
# <li class="menu-right-list-item zhidao-app">
# <a class="menu-right-list-link" href="/activity/simpleindexact?tplName=nareplace&amp;type=pc" target="_blank">
# <span class="phone-icon"></span>
# <span class="item-name">
# ææºç­é¢</span>
# </a>
# </li>
# <li class="menu-right-list-item user-center">
# <a class="menu-right-list-link" href="/ihome" target="_blank">
# <span class="item-icon">
# </span>
# <span class="item-name">
# æç</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#             // å¯¼èªå¯ç¨æ¶é´
#             window.iPerformance && window.iPerformance.mark('c_menu', +new Date);
#         </script>
# <div class="container" id="body">
# <div class="layout-wrap">
# <div style="display:none">
# <nav alog-group="qb-cate-nav" class="wgt-nav f-12">
# <a href="/">ç¾åº¦ç¥é</a>
# &gt; æ åç±»</nav>
# </div>
# <section class="line qb-section">
# <article class="grid qb-content" id="qb-content">
# <div class="shadow-task">
# <div class="shadow-task-show-box">
# <img class="shadow-task-show-img" loading="lazy" src="https://iknow-base.cdn.bcebos.com/lxb/notice.png">
# <div class="shadow-task-show"></div>
# </img></div>
# </div>
# <div class="wgt-ask accuse-response line" id="wgt-ask">
# <h1 accuse="qTitle">
# <span class="ask-title">currentæ¯ä»ä¹ææ</span>
# </h1>
# <div class="q-video">
# </div>
# <div class="line f-aid ask-info ff-arial" id="ask-info">
# <div class="line wgt-replyer-line">
# <span alog-alias="qb-answer-bar" class="iknow-icons exp-answerbtn-yh" id="answer-bar"> ææ¥ç­</span>
# <ins class="share-area cannotanswer"></ins>
# <ins class="accuse-area cannotanswer"></ins>
# <span id="v-times"></span>
# </div>
# <div class="line" data-realname="" id="answer-editor"></div>
# <script id="replyer-addtags-tmpl" type="text/html">
# <div class="addtags-box">
#     <div class="addtags-mask"></div>
#     <div class="addtags-content">
#         <i class="iknow-qb_replyer_icons i-ask-close addtags-close"></i>
#         <div class="addtags-head"><div class="addtags-head-img"></div><span>æäº¤æå</span></div>
#         <div class="addtags-subhead">éæ©æé¿çé¢åç»§ç»­ç­é¢ï¼</div>
#         <div class="tags-box">
#             {@each tagList as item}
#             <li class="{@if item.isQuesTag && item.isQuesTag == 1}selected{@/if}">${item.tagName}</li>
#             {@/each}
#         </div>
#         <div class="addtags-bottom">
#             <div class="addtags-sub">ç»§ç»­åç­</div><div class="addtags-notip ml-10">ä¸åæç¤º</div>
#         </div>
#         <div class='download-app-tip'>
#             <span class="phone-icon-green"></span>
#             <span class="tip-text">ææºåç­æ´æ¹ä¾¿ï¼äºå¨æ´æè¶£ï¼</span><a href='/activity/simpleindexact?tplName=nareplace&type=pc' class="tip-text tip-download-now">ä¸è½½APP</a>
#         </div>
#     </div>
# </div>
# </script>
# <script id="replyer-tags-tmpl" type="text/html">
# <div class="tags-box">
#     <div class="tags-mask"></div>
#     <div class="tags-content">
#         <i class="iknow-qb_replyer_icons i-ask-close tags-close"></i>
#         <div class="tags-head">æäº¤æå</div>
#         <div class="tags-subhead">æ¯å¦ç»§ç»­åç­é®é¢ï¼</div>
#         <div class="tags-bottom">
#             <div class="tags-sub">ç»§ç»­åç­</div><div class="tags-notip ml-10">ä¸åæç¤º</div>
#         </div>
#         <div class='download-app-tip'>
#             <span class="phone-icon-green"></span>
#             <span class="tip-text">ææºåç­æ´æ¹ä¾¿ï¼äºå¨æ´æè¶£ï¼</span><a href='/activity/simpleindexact?tplName=nareplace&type=pc' class="tip-text tip-download-now">ä¸è½½APP</a>
#         </div>
#     </div>
# </div>
# </script>
# <script id="answer-for-lottery" type="text/html">
#     <div class="affairs-box answer-for-lottery">
#         <div class="affairs-mask"></div>
#         <div class="affairs-content">
#             <i class="iknow-qb_replyer_icons i-ask-close affairs-close"></i>
#             <a log="pos:government-affairs-act,action:click" href="https://zhidao.baidu.com/shop/lottery?from=datichoujiang" class="affairs-img">
#                 <img src="https://iknow-base.cdn.bcebos.com/answer-for-lottery.png">
#             </a>
#         </div>
#     </div>
# </script>
# <script id="visit-join-model-template" type="text/html">
#     <p class="visit-join-model-title">å å¥å¢éï¼åä¸ç¾¤å¿åéåä¹äººç¸ç»è¯ï¼ä¸èµ·å¸®å©æ´å¤äºº</p>
#     <div class="visit-join-model-content" id="visit-join-model-content">
#         <div class="carousel-misc"><a href="javascript:void(0);" data-action="left" class="visit-join-control visit-join-control-left visit-join-control-left-disable"></a><a href="javascript:void(0);" data-action="right" class="visit-join-control visit-join-control-right"></a></div>
#     </div>
#     <div class="visit-join-model-warn" id="visit-join-warn">è¯·åéæ©ä¸ä¸ªè¦å å¥çå¢é</div>
# </script>
# </div>
# </div>
# <script>
#     // æé®åºåå¯ç¨æ¶é´
#     window.iPerformance && window.iPerformance.mark('c_ask', +new Date);
# </script>
# <div class="question-all-answers-number">
# <span class="question-all-answers-line"></span>
# <span class="question-all-answers-title" style="font-weight: 700;">1ä¸ªåç­</span>
# <div class="question-number-text-chain">
# <a class="text-chain-wrapper" href="https://zhidao.baidu.com/question/507785574610459284/answer/4450848674?fr=nashare&amp;entry=qb_hotRecommend" log="module:question,page:question,action:click,area:question_text_chain" target="_blank">
# <span class="text-chain-title">#ç­è®®#</span>
# <span class="text-chain-content">ä»ä¹æ¯æ·çï¼åªäºè¡ä¸ºä¼æææ·çï¼</span>
# </a>
# </div>
# </div>
# <script>
#                     // é«è´¨oræ»¡æorç¹åoræ¨èç­æ¡æç¹æ¶é´
#                     window.iPerformance && window.iPerformance.mark('c_best', +new Date);
#                 </script>
# <div class="wgt-answers" id="wgt-answers">
# <div class="bd-wrap">
# <script type="text/javascript">
#                     F.context('answers')['4453651700'] = {uid:"6469756694",imId:"public.1.220274dc.NkDYlFbkPclFrgNWZCjdSg",id:"4453651700",userName:"Haozhicong999",userNameEnc:"Haozhicong999",user:{sex:"1",iconType:"6",gradeIndex:"20",grAnswerNum:"743927",isAuth:"0",authTitle:"",isUserAdmin:"0",userAdminLevel:"",userAdminTitle:"",userAdminType:"",isFamous:"0",isMaster:"0",goodRate:"99"},isAnonymous:"0",isCurrentUser:"0",mapUrl:"",refer:"",replyAskNum:"",threadId:"17814606801",hasComment:"0",qid:"635787571195459284",raid:"",recommendCanceled:"0"};
#                     F.context('answers')['4453651700']['c_timestamp'] = '1691374217';
#                                             F.context('answers')['4453651700'].encodeUid = '16a74069236f25705e79ga08101000000';
#                                                                 F.context('answers')['4453651700'].ext_pack = {"business":{"businessId":"142946"},"display_best_for_se":"1","display_best_for_se_time":"1691381701","hosted_content_from":"hehuoren_tuoguan","ignore_spam":"15","mode_begintime":"0","mode_qtype":"0","op_uid":"0","partner":[]};
#                                                                 F.context('answers')['4453651700'].bit_pack = {"is_recommend":"0","wap_flag":"0","is_pic_contained":"1","media_flag":"0","help_flag":"0","anonymous":"0","is_really_anonymous":"0","level_new":"1","comment_flag":"0","in_mis":"0","auto_recommend":"0","content_rich_flag":"1","prior_flag":"0","hidden_flag":"0","rec_canceled_flag":"0","mis_flag":"0","file_flag":"0","read_flag":"0","is_challenge":"0","ikaudio_flag":"0","mavin_flag":"0","is_delete_lock":"0","authentic_state":"0","is_compulsory_best":"0","dynamic_stick_flag":"0","video_flag":"0","vote_affirmative":"0","vote_negative":"0","is_video":"0","is_baiduyun":"0","is_yike_card":"0","is_baidumap":"0","is_note":"0"};
#                                                         </script>
# <div class="bd answer answer-last answer-fold" data-createtime="1691374217" id="answer-4453651700">
# <div class="hd line">
# </div>
# <div class="wgt-replyer-all" id="wgt-replyer-all-4453651700">
# <a class="reply-user-tohometip" href="https://zhidao.baidu.com/business/profile?id=142946&amp;role=business" target="_blank">
# <div class="wgt-replyer-all-avatar" style="background-image: url(https://pic.rmb.bdstatic.com/bjh/bjh/user/1a4f97a5cb380978403a38e63fbbcac6.jpeg)">
# </div>
# </a>
# <span class="wgt-replyer-all-v ikonw-qb-new-icon wgt-replyer-all-v-star"></span>
# <a class="reply-user-tohometip" href="https://zhidao.baidu.com/business/profile?id=142946&amp;role=business" target="_blank">
# <span class="wgt-replyer-all-uname">
# èµ·èªç¥è¯å°ç¾ç§
# </span>
# </a>
# <br/>
# <span class="wgt-replyer-all-box">
# <span class="wgt-replyer-all-time">
# 2023-08-07
# </span>
# <span>Â·</span>
# <span class="wgt-replyer-all-slogan">
# æ·®å®èµ·èªç®¡çå¹è®­å¬å¸ä¸æ³¨ä¼ä¸ç®¡çç¥è¯åäº«</span>
# </span>
# <div class="wgt-replyer-all-card">
# <div class="wgt-replyer-all-triangle1"></div><div class="wgt-replyer-all-triangle2"></div>
# <img class="wgt-replyer-all-card-avatar1 wgt-replyer-all-card-avatars" data-href="https://zhidao.baidu.com/business/profile?id=142946&amp;role=business" src="https://pic.rmb.bdstatic.com/bjh/bjh/user/1a4f97a5cb380978403a38e63fbbcac6.jpeg"/>
# <span class="wgt-replyer-all-v wgt-replyer-all-card-v wgt-replyer-all-v-star ikonw-qb-new-icon"></span>
# <span class="wgt-replyer-all-card-name1 wgt-replyer-all-card-names" data-href="https://zhidao.baidu.com/business/profile?id=142946&amp;role=business">
# èµ·èªç¥è¯å°ç¾ç§
# </span>
# <div class="wgt-replyer-all-card-bussiness-intro"></div>
# <a class="wgt-replyer-all-card-ask1" href="/new?targetEncodeUid=16a74069236f25705e79ga08101000000&amp;id=142946" target="_blank">åTAæé®</a>
# </div>
# <div class="wgt-replyer-all-follow-box">
# <span class="wgt-replyer-all-follow" data-follow="0" data-gtype="ugc">å³æ³¨</span>
# <img class="follow-animation" data-src="https://wyw-base.cdn.bcebos.com/pc-content/follow.gif"/>
# </div>
# </div>
# <div class="line content-wrapper">
# <div class="line content" data-valuerrank="0">
# <div accuse="aContent" class="answer-text mb-10" id="answer-content-4453651700">
# <div class="wgt-answers-mask">
# <div class="wgt-answers-showbtn">
# å±å¼å¨é¨<span class="wgt-answers-arrowdown"></span>
# </div>
# </div>
# <div class="rich-content-container rich-text-">
# <p><strong>currentï¼ä½åè¯è¯ä¸ºï¼æ°´ï¼æ°ï¼çµï¼æµï¼è¶å¿ï¼ä½å½¢å®¹è¯è¯ä¸ºç°å¨çï¼æµéçã</strong></p><p></p><p>è¯»é³ï¼è±ï¼»ˈkʌrənt]ï¼ç¾ï¼»ˈkɜːrənt]ã</p><p>éä¹ï¼</p><p>adj.ç°å¨çï¼æµéçï¼éç¨çï¼æè¿çï¼èåçã</p><p>n.ï¼æ°´ï¼æ°ï¼çµï¼æµï¼è¶å¿ï¼æ¶æµã</p><p>ä¾å¥ï¼The current price of the stock is not very stable.</p><p>é£åªè¡ç¥¨æ¶ä»·ä¸å¤ªç¨³å®ã</p><p>åå½¢ï¼å¤æ°currentsã</p><p>ç­è¯­ï¼</p><p>current beliefæ®éçè§ç¹</p><p>the main currentä¸»æµ</p><p>apply the currentéçµ</p><p>reverse the currentæ­è½¬å±å¿</p><p>direct currentç´æµï¼ï¼»çµï¼½ç´æµçµ</p><p><a class="ikqb_img_alink" href="https://iknow-pic.cdn.bcebos.com/10dfa9ec8a136327128e5a529f8fa0ec08fac774" target="_blank" title="ç¹å»æ¥çå¤§å¾"><img class="ikqb_img" esrc="https://iknow-pic.cdn.bcebos.com/10dfa9ec8a136327128e5a529f8fa0ec08fac774" loading="lazy" src="https://iknow-pic.cdn.bcebos.com/10dfa9ec8a136327128e5a529f8fa0ec08fac774?x-bce-process=image%2Fresize%2Cm_lfit%2Cw_600%2Ch_800%2Climit_1%2Fquality%2Cq_85%2Fformat%2Cf_auto"/></a></p><p><strong>currentçè¿ä¹è¯</strong></p><p>recent</p><p>è¯»é³ï¼è±ï¼»ˈriːsnt]ï¼ç¾ï¼»ˈriːsnt]ã</p><p>éä¹ï¼adj.æè¿çï¼è¿ä»£çã</p><p>ä¾å¥ï¼She made a reference to her recent book.</p><p>å¥¹æå°äºèªå·±æè¿çé£æ¬ä¹¦ã</p><p></p><p>å¯è¯ï¼recently</p><p>åè¯ï¼recency</p><p>ç­è¯­ï¼</p><p>recent acquaintanceæ°æå</p><p>recent eventä¸ä¹ååççäºä»¶</p><p>recent historyè¿ä»£å²</p><p>recent newsæ°é»æ¶æ¯</p><p>recent researchè¿æ¥çç ç©¶</p><p>recent yearsè¿äºå¹´</p>
# </div>
# </div>
# <div class="businessvip-wrapper businessvip-clew-4453651700">
# <div class="clew-item clew-4" data-url="https://m.ctrip.com/html5/?ouid=kfptpctool&amp;allianceid=3854141&amp;sid=22342061">
# <div class="clew-brand-bg" style="background-image: url(
#                 https://iknow-pic.cdn.bcebos.com/3c6d55fbb2fb4316675854f232a4462308f7d3f6?x-bce-process=image/resize,m_fill,w_1140,h_186,limit_1/quality,q_85/format,f_auto
#             )"></div>
# <div class="detail-more">
# <span class="detail-content">è¯¦æ</span>
# <i class="zhidao-icon detail-icon"></i>
# </div>
# </div>
# </div>
# <div class="line info f-light-gray mt-10 mb-5 f-12">
# <div class="wgt-answers-operator f-aid">
# <img class="wgt-answers-operator-shadow" src="data:image/jpeg;base64,..."/>
# <div class="wgt-eva" id="wgt-eva-4453651700">
# <span alog-action="qb-zan-btn" class="evaluate evaluate-32 evaluate-good-0" data-evaluate="0" id="evaluate-4453651700">
# <i class="ikonw-qb-new-icon icon-evaluate"></i>
# <b class="evaluate-num"></b>
# </span>
# <span class="wgt-eva-pipe"></span>
# <span alog-action="qb-evaluate-outer" class="evaluate-bad evaluate-32" data-evaluate="0" id="evaluate-bad-4453651700">
# <i class="ikonw-qb-new-icon icon-evaluate-bad"></i>
# <b class="evaluate-num"></b>
# </span>
# <span class="wgt-eva-hasgood"><i class="ikonw-qb-new-icon icon-evaluated"></i><b class="evaluate-text">å·²èµè¿</b></span>
# <span class="wgt-eva-hasbad"><i class="ikonw-qb-new-icon icon-evaluated-bad"></i><b class="evaluate-text">å·²è¸©è¿</b>&lt;</span>
# <div class="eva_tooltip">
# <div class="eva_tooltip_arrow">
# <div class="eva_tooltip_arrow_inner"></div>
# </div>
# <div class="eva_tooltip_context">
# ä½ å¯¹è¿ä¸ªåç­çè¯ä»·æ¯ï¼</div>
# </div>
# </div>
# <span alog-action="qb-comment-btn" class="comment" id="comment-4453651700"><i class="ikonw-qb-new-icon qb-comment-icon"></i>è¯è®º</span>
# <ins class="share-area"></ins>
# <ins alog-action="qb-accuse-link" class="accuse-area" data-rid="4453651700"></ins>
# <span class="wgt-answers-hidebtn">æ¶èµ·<i class="wgt-answers-arrowup"></i></span>
# </div>
# </div>
# </div>
# </div></div>
# <div class="knowledge-answer fc-47ed09047ec95944" data-bd_bxst="EiaKw7MFx6fFeRxeK00G0jzWHfc0000000000K7WIgFzuy4Yz_x2__rYY8QQE000000000000a0snj0snj0snj0snj0snj0snj0snj0snj0snj0snj0snAbCf9ayRUEp0f000KL0BZCf0000IASjimn0000-00000KF-ULQhh2Ob83jb8mWh9cOh6FY00000OOOOOOOOOOSDqW7b" data-bd_vid="PHD3nW6srjmvnH03PjbdnWbsn7tknWTdg1Kxn7tYnNtLnjTLPHcdrHDvPf" data-ecimtimesign="61" data-expid="1" data-href="https://sp0.baidu.com/9q9JcDHa2gU2pMbgoY3K/km.php?t=FzXRpf0000KDyT-SK0MVwzsK00000rsj52PP0oKLa600000006C50ZwE6Yhj0000argGo0000000000000000ZwupCbK05I2.uHdCIZwsT1CEQvF1QhF9pywdQhPEUiqsIyF_pynsnzqsmz4Mpym0THdWIgFzuy4Yz_x2__rYY8QQE0KWp1Ysnj0snj0snj0snj0snj0snj0snj0snj0snj0snj0sn0K95y3qnWc3PsFVIjYYnj0z0MIV5H0aThTqn1Ixn0FYIjYk0MKWIZcqna3Ynj0zPjDauMnqn0FhIjYs0huh5H0amhfqnHRs0M7GujYs06KWThnqPH6vPjR0" data-log="fr:question,pos:qb-answer-uname,si:0,st:2" data-midexpid="8" data-pz-sign="61" data-qid="2212765169101794948" data-qsign="mLNzThN8IrpmoSie6ri4BrpDWSp0Mf" data-sign="1771317031977" data-url="http://www.baidu.com/baidu.php?url=Ks0000KJ6AMt6olXulmzxX7MVlCBe5cD02xfwO9K0rs6a1B63Jhqmm_wDr0qSi7q0iOpHihG3xmkxpzXxzTPzlo0sy6sZsJn81SvOnKlmm3xoWD30qY89Cv9FLSMSGXYg1WMS_dnHPlxwPwYNUp35Kj-TT3ARqoswbOACE22xZfdZ4Y1XS04Ja_WjnAk7wuyKutU2c_Syaph63ydOkRiVUBP4eZi.DR_NR2Ar5Od663mqZw4g_3_acPrQA1JHKePZKILqhFWFbozX5H8olIqI-xWEePOu_lkpTUDgeItTgeqbTLeSMqTgHdBY3Sg0k7gYOwSUQjOvFEL3XEjZClA51xEOQW7SLYk1uI5YwxEvTx1uUeCEve33EA9g7-_lq8-tyV17xHdd3h51xEOQW7SLYk1uI5YwxEvTx1uUeCEve33EA9vkxVOCgpJO-dqbUqRHAMqx4XZqaot81e1mqQEkXMGhxvX_v54xVOWW_OBpSJXWZBmvIxCHnkbllpDzmob1nNqXBr6kqle_OS1SEtqNyHSWx_34UqhMq8oxjOwJlxoOv5OKqOLOSkgP-YOqBQqEgvwI5WSLWzLXEl7gW_syX5j8O3AWkO3VWY4qhWOutOSKCvxtgH3OJUELO-vOhqX5AuOZVBzlIbgetglePgHe51uxEMsuUrzQQoOg6YwIM4ELeOSkSUkCI_LeOzSWNgjvwux-Z7-ESWtdT5O6OfoOe7YgeOHs1uUr54Evq5U7-lxSkPSOOo3uELecqNxz3x1NO-lco5-sOholX1tLexlZOmhOxSgp_HjSvFL0_nYQ7IMukz20.U1Yk0ZDqdJo2VVrJ1OJOdN7NwNFu_XJtksKY5fKGUHYknWTd0ZNG5fKspyfqn1T0mv-b5H00mhbqn0KhIjYs0ZKC5H00ULnqn0KBI1Ys0A4Y5H00TLCq0ZFMIA7M5H00UMus5H08nj0snj0snj00ugFM5H00IZF9uARqn0KBuA-b5fKbmvPb5fKYmgFMugfqn7tsg100mgPxpywW5gK1Qy4J0APdujYs0AqW5HD0u1dLTv410AqsnHYs0ZKsPjYs0ZFY5iYk0Z7spyfqn0Kkmv-b5H00mycqn7ts0ZKs5H00Ugws5H00uAwETjYs0ZFJ5H00IZN15HDdP101nWnLrjnzPWbLnjnsrH6k0A7W5HD0TA3qn0Ksmgwxuhk9u1Ys0Z7MIvfqn0K-TLfqn0K-IA-b5iYk0A71TAPW5H00IgKGUhPW5H00uhPdIjYs0A7buhk9u1YkPWn3P0KLuMFEUHY0mMfqn0K3TLwd5Hn3PWfzPjbz0A-W5H00ThNkIjYkP1Tkn1DLnjnkrj6v0ZPGujYYPvNbnjbsPjI-m1bdrHfY0AqY5H00ULFsIjYV0ZFYmy-b5fKopHYs0AdY5H61njR0Uynqn0KVmdqhThqV5H00uA78IyF-gLK_my4GuZnqn0KGTvP_5H00pyw-my-b5HTsP1TdnWR4nHmd0A4-IdqsUA785HcLnWTLnHDLPsK8ugIxIy4GIjYLrHmYPWTvPH0z0A4-IdqGuAN95HTsP1TdnWR4nHmd0ZK9TLPsULFY5H00mh7GuZNGujY0ULPGujYs0A7bgLPEIgFWuHYkranW0APzm1YdPHD1r0&amp;us=newvui&amp;xst=m1YKT1YdnH6zrj03PWmknj6YrHRzrH0sg1DzP1Nxn07L5f7k5IpJzoUHJ_OlEqNkIyNzXUZJEnTKIHY1rjmYnWf4n67Y5HDLP1D1nHTsn1DKUgDqnfcs0BYKmv6qmMF9UhfKTMfqn0D1n1bLPWRvP1Ts&amp;word=" data-zsyx="PHD3nW6srjmvnH03PjbdnWbsn7t1nj0" id="knowledge-answer">
# <div class="knowledge-answer-replyer">
# <img class="knowledge-answer-replyer-avatar" src="https://ecmc.bdimg.com/public03/b4cb859ca634443212c22993b0c87088.png"/>
# <span class="knowledge-answer-replyer-uname">èä»ç¦</span>
# <br/>
# <span class="knowledge-answer-replyer-box">
# <span class="knowledge-answer-replyer-time">2023-07-11</span>
# </span>
# <span class="knowledge-answer-tip">å¹¿å</span>
# </div>
# <div class="knowledge-answer-content">
# <span class="inline-link">
# eoræä»¥ä¸ä¸¤ç§å«ä¹ï¼1. eoræ¯è®¡ç®æºæ¯è¯­ï¼è¡¨ç¤ºäºè¿å¶å¼æè¿ç®ãå¨è®¡ç®æºé»è¾è¿ç®ä¸­ï¼ç®æ¯é»è¾æ§è¡äºè¿å¶æä½å¼æè¿ç®ï¼ä¸¤æ°æ§è¡å¼æåç¸åä½ç»æä¸º0ï¼ä¸åä½ç»æä¸º1ã2. eorä¹è¡¨ç¤ºå¨ä»»ä½æ¶æï¼åå°å±ä¸­æ³¨å¥æµä½ãè½éï¼ä»¥æé«äº§éæéæ¶çç...
# <span class="green">ç¹å»è¿å¥è¯¦æé¡µ</span>
# </span>
# </div>
# <div class="knowledge-answer-from">
# æ¬åç­ç±<span class="green">èä»ç¦</span>æä¾</div>
# <img class="bottom-dashed-line" src="data:image/png;base64,..."/>
# </div>
# <script>
#         !function(t){"use strict";function e(t,e){if(t){var n=new Date().getTime(),r=new Image;t+="&rand="+(n+Math.random()),window.ecomLogImage||(window.ecomLogImage={}),window.ecomLogImage["--IMAGE"+n]=r,e=e||{};var o=!1;r.onload=r.onerror=r.onabort=function(i){if(!e.charge){if(i&&"load"!==i.type){if(o)"error"in e&&e.error();else{r.src=t,o=!0;return}}else"load"in e&&e.load()}r.onload=r.onerror=r.onabort=null,window.ecomLogImage["--IMAGE"+n]=null,r=null},r.src=t}}var n,r=function(){var t,e,n,r=0,o=0,i=0,a=0,s=0,c=0,u=0,f=0,h=/link\?url\=([^\&]+)/,l=/\?url\=([^\.]+)\./,d="data-cklink",p=/[?&]tn=([^&]*)/;function v(t){if(!t)return!1;var e=h.exec(t)||l.exec(t);return!!e&&(h.exec(t)?e[1].length<20?e[1]:e[1].substr(0,20):e[1])}function g(n){var a,s,h,l,p,g=(l=f.href,p=f.getAttribute(d),v(l)||v(p));!1!==g&&(a="&ck="+[function(t,e){for(var n=0,r=0;r<i*e%99+9;r++)n+=t.charCodeAt(u*r%t.length);return n}(g,n),i,u,Math.round(r),Math.round(o),Math.round(t),Math.round(e),c].join("."),s=f.href,h=f.getAttribute(d),s&&v(s)&&(f.href=y(s,a)+m(s)),h&&v(h)&&f.setAttribute(d,y(h,a)+m(h)))}function m(t){var e="";if(-1===t.indexOf("&shh=")&&-1===t.indexOf("?shh=")&&(e="&shh="+location.hostname),-1===t.indexOf("&sht=")&&-1===t.indexOf("?sht=")){var n=location.href.match(p);n&&(e+="&sht="+n[1])}return e}function y(t,e){return v(t)&&(-1===t.indexOf("&ck=")?t+=e:t=t.replace(/&ck=[\d.]*/,e)),t}function b(n,h,l){void 0===n.length&&(n=[n]);for(var p=n.length,b=0,w=[function(n){var s;f=(s=(s=n)||window.event).target||s.srcElement,i++,void 0===t&&(t=s.clientX),void 0===e&&(e=s.clientY),r=0,o=0,u=0,c=0,a=new Date().getTime(),g(h)},function(t){!function(t,e){for(f=(t=t||window.event).target||t.srcElement;f&&"A"!==f.tagName;)f=f.parentNode;s=new Date().getTime(),u=9999,r=t.clientX,o=t.clientY,c=0===a?0:s-a,g(e)}(t,h)},function(t){u=new Date().getTime()-s,g(h)}];b<p;b++)l||function(t){var e=t.href;if(v(e)){var n="&ck="+[0,i,u,Math.round(r),Math.round(o),0,0,c].join("."),a=t.getAttribute(d);e&&(t.href=y(e,n)+m(e)),a&&t.setAttribute(d,y(a,n)+m(a))}}(n[b]),function(t,e,n){for(var r,o,i=e.length,a=0;a<i;a++)r=e[a],o=n[a],window.attachEvent?t.attachEvent("on"+r,o):t.addEventListener(r,o,!1)}(n[b],["mouseover","mousedown","mouseup"],w)}return{getInstance:function(t){return n||(n={addAdsCk:b}),n}}},o={init:function(t,e,o,i){var a,s=document.querySelectorAll(t);if(null==i?void 0:null===(a=i.flags)||void 0===a?void 0:a.expFlagPreventCkRepeatBind)for(var c=0;c<s.length;c++){var u=s[c];if("1"===u.dataset.isCkBinded)return;u.dataset.isCkBinded="1"}var f=r().getInstance(t);n=f;for(var h=0;h<s.length;h++){var l=s[h],d=l.getAttribute("data-ecimtimesign")||l.getAttribute("data-pz-sign")||e,p=l.getElementsByTagName("A");f.addAdsCk(p,d,o)}return f},getInstance:function(){return n}},i="undefined"!=typeof globalThis?globalThis:"undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:{},a={exports:{}};!function(t){var e=Object.prototype.hasOwnProperty,n="~";function r(){}function o(t,e,n){this.fn=t,this.context=e,this.once=n||!1}function i(t,e,r,i,a){if("function"!=typeof r)throw TypeError("

# %%
# extract text
weather_data = []
for tag in soup.find_all(['h1', 'h2', 'h3', 'p']):
    text = tag.get_text(" ", strip=True)
    weather_data.append(text)

# combine all elements into a single string
weather_data = "\n".join(weather_data)

# remove all spaces from the combined text
weather_data = re.sub(r'\s+', ' ', weather_data)
    
print(f"Website: {url}\n\n")
print(weather_data)
# Out:
# Website: https://zhidao.baidu.com/question/635787571195459284.html
#
#
# currentæ¯ä»ä¹ææ currentæ¯ä»ä¹ææ currentï¼ä½åè¯è¯ä¸ºï¼æ°´ï¼æ°ï¼çµï¼æµï¼è¶å¿ï¼ä½å½¢å®¹è¯è¯ä¸ºç°å¨çï¼æµéçã è¯»é³ï¼è±ï¼»ˈkʌrənt]ï¼ç¾ï¼»ˈkɜːrənt]ã éä¹ï¼ adj.ç°å¨çï¼æµéçï¼éç¨çï¼æè¿çï¼èåçã n.ï¼æ°´ï¼æ°ï¼çµï¼æµï¼è¶å¿ï¼æ¶æµã ä¾å¥ï¼The current price of the stock is not very stable. é£åªè¡ç¥¨æ¶ä»·ä¸å¤ªç¨³å®ã åå½¢ï¼å¤æ°currentsã ç­è¯­ï¼ current beliefæ®éçè§ç¹ the main currentä¸»æµ apply the currentéçµ reverse the currentæ­è½¬å±å¿ direct currentç´æµï¼ï¼»çµï¼½ç´æµçµ currentçè¿ä¹è¯ recent è¯»é³ï¼è±ï¼»ˈriːsnt]ï¼ç¾ï¼»ˈriːsnt]ã éä¹ï¼adj.æè¿çï¼è¿ä»£çã ä¾å¥ï¼She made a reference to her recent book. å¥¹æå°äºèªå·±æè¿çé£æ¬ä¹¦ã å¯è¯ï¼recently åè¯ï¼recency ç­è¯­ï¼ recent acquaintanceæ°æå recent eventä¸ä¹ ååççäºä»¶ recent historyè¿ä»£å² recent newsæ°é»æ¶æ¯ recent researchè¿æ¥çç ç©¶ recent yearsè¿äºå¹´ ä¸ºä½ æ¨èï¼ ç¹å«æ¨è ç­ä½ æ¥ç­ ç±»å« æä»¬ä¼éè¿æ¶æ¯ãé®ç®±ç­æ¹å¼å°½å¿«å°ä¸¾æ¥ç»æéç¥æ¨ã è¯´æ 0 /200 æçè´¢å¯å¼ 0 -- æçç°é 0 ä¸è½½ç¾åº¦ç¥éAPP å¨APPç«¯-ä»»å¡ä¸­å¿æç° æç¥éäº -- ç´¯è®¡å®æ ä¸ªä»»å¡ 10ä»»å¡ ç¥ç¥ç¥ç¥â¦ 50ä»»å¡ ç¥ç¥ç¥ç¥â¦ 100ä»»å¡ ç¥ç¥ç¥ç¥â¦ 200ä»»å¡ ç¥ç¥ç¥ç¥â¦ æ¨çè´¦å·ç¶ææ­£å¸¸ æè°¢æ¨å¯¹æä»¬çæ¯æ äº¬ICPè¯030173å·-1 äº¬ç½æã2023ã1034-029å· ©2026Baidu ä½¿ç¨ç¾åº¦åå¿ è¯» | ç¥éåè®® | ä¼ä¸æ¨å¹¿ è¾ å© æ¨¡ å¼

# %% [markdown]
# ## Agentic Search

# %%
# run search
result = client.search(query, max_results=1)

# print first result
data = result["results"][0]["content"]

print(data)
# Out:
# {'location': {'name': 'Singapore', 'region': '', 'country': 'Singapore', 'lat': 1.293, 'lon': 103.856, 'tz_id': 'Asia/Singapore', 'localtime_epoch': 1771317113, 'localtime': '2026-02-17 16:31'}, 'current': {'last_updated_epoch': 1771317000, 'last_updated': '2026-02-17 16:30', 'temp_c': 24.0, 'temp_f': 75.2, 'is_day': 1, 'condition': {'text': 'Light rain', 'icon': '//cdn.weatherapi.com/weather/64x64/day/296.png', 'code': 1183}, 'wind_mph': 5.6, 'wind_kph': 9.0, 'wind_degree': 332, 'wind_dir': 'NNW', 'pressure_mb': 1008.0, 'pressure_in': 29.77, 'precip_mm': 2.57, 'precip_in': 0.1, 'humidity': 100, 'cloud': 75, 'feelslike_c': 25.9, 'feelslike_f': 78.6, 'windchill_c': 27.1, 'windchill_f': 80.7, 'heatindex_c': 30.3, 'heatindex_f': 86.6, 'dewpoint_c': 23.1, 'dewpoint_f': 73.7, 'vis_km': 6.0, 'vis_miles': 3.0, 'uv': 1.5, 'gust_mph': 10.3, 'gust_kph': 16.6}}

# %%
import json
from pygments import highlight, lexers, formatters

# parse JSON
parsed_json = json.loads(data.replace("'", '"'))

# pretty print JSON with syntax highlighting
formatted_json = json.dumps(parsed_json, indent=4)
colorful_json = highlight(formatted_json,
                          lexers.JsonLexer(),
                          formatters.TerminalFormatter())

print(colorful_json)
# Out:
# {
#     "location": {
#         "name": "Singapore",
#         "region": "",
#         "country": "Singapore",
#         "lat": 1.293,
#         "lon": 103.856,
#         "tz_id": "Asia/Singapore",
#         "localtime_epoch": 1771317113,
#         "localtime": "2026-02-17 16:31"
#     },
#     "current": {
#         "last_updated_epoch": 1771317000,
#         "last_updated": "2026-02-17 16:30",
#         "temp_c": 24.0,
#         "temp_f": 75.2,
#         "is_day": 1,
#         "condition": {
#             "text": "Light rain",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/296.png",
#             "code": 1183
#         },
#         "wind_mph": 5.6,
#         "wind_kph": 9.0,
#         "wind_degree": 332,
#         "wind_dir": "NNW",
#         "pressure_mb": 1008.0,
#         "pressure_in": 29.77,
#         "precip_mm": 2.57,
#         "precip_in": 0.1,
#         "humidity": 100,
#         "cloud": 75,
#         "feelslike_c": 25.9,
#         "feelslike_f": 78.6,
#         "windchill_c": 27.1,
#         "windchill_f": 80.7,
#         "heatindex_c": 30.3,
#         "heatindex_f": 86.6,
#         "dewpoint_c": 23.1,
#         "dewpoint_f": 73.7,
#         "vis_km": 6.0,
#         "vis_miles": 3.0,
#         "uv": 1.5,
#         "gust_mph": 10.3,
#         "gust_kph": 16.6
#     }
# }
